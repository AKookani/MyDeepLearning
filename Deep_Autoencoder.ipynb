# %%
from keras.datasets import mnist
import numpy as np

(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
import matplotlib.pyplot as plt

n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
import tensorflow as tf

input_img = tf.keras.Input(shape=(28, 28, 1))

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_4 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 32)        9248
#
#  max_pooling2d_5 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 7, 7, 32)          9248
#
#  up_sampling2d_4 (UpSamplin  (None, 14, 14, 32)        0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 14, 14, 32)        9248
#
#  up_sampling2d_5 (UpSamplin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28353 (110.75 KB)
# Trainable params: 28353 (110.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=80,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))
# Out:
# Epoch 1/80
# 469/469 [==============================] - 5s 7ms/step - loss: 0.1752 - val_loss: 0.1176
# Epoch 2/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1132 - val_loss: 0.1086
# Epoch 3/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1078 - val_loss: 0.1050
# Epoch 4/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1050 - val_loss: 0.1035
# Epoch 5/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1031 - val_loss: 0.1013
# Epoch 6/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1017 - val_loss: 0.1004
# Epoch 7/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1006 - val_loss: 0.0995
# Epoch 8/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0998 - val_loss: 0.0988
# Epoch 9/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0991 - val_loss: 0.0983
# Epoch 10/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0986 - val_loss: 0.0979
# Epoch 11/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0982 - val_loss: 0.0977
# Epoch 12/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0978 - val_loss: 0.0969
# Epoch 13/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0974 - val_loss: 0.0966
# Epoch 14/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0971 - val_loss: 0.0965
# Epoch 15/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0969 - val_loss: 0.0962
# Epoch 16/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0967 - val_loss: 0.0960
# Epoch 17/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0965 - val_loss: 0.0960
# Epoch 18/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0963 - val_loss: 0.0958
# Epoch 19/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0961 - val_loss: 0.0957
# Epoch 20/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0960 - val_loss: 0.0953
# Epoch 21/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0958 - val_loss: 0.0952
# Epoch 22/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0957 - val_loss: 0.0955
# Epoch 23/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0956 - val_loss: 0.0951
# Epoch 24/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0955 - val_loss: 0.0950
# Epoch 25/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0953 - val_loss: 0.0949
# Epoch 26/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0952 - val_loss: 0.0948
# Epoch 27/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0952 - val_loss: 0.0949
# Epoch 28/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0951 - val_loss: 0.0948
# Epoch 29/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0950 - val_loss: 0.0945
# Epoch 30/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0949 - val_loss: 0.0945
# Epoch 31/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0949 - val_loss: 0.0944
# Epoch 32/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0948 - val_loss: 0.0945
# Epoch 33/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0948 - val_loss: 0.0943
# Epoch 34/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0943
# Epoch 35/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0947 - val_loss: 0.0944
# Epoch 36/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0946 - val_loss: 0.0943
# Epoch 37/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0945 - val_loss: 0.0944
# Epoch 38/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0945 - val_loss: 0.0940
# Epoch 39/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0945 - val_loss: 0.0941
# Epoch 40/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.0943
# Epoch 41/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0944 - val_loss: 0.0942
# Epoch 42/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0945
# Epoch 43/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 44/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0940
# Epoch 45/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0943 - val_loss: 0.0939
# Epoch 46/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0939
# Epoch 47/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0941 - val_loss: 0.0940
# Epoch 48/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0937
# Epoch 49/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0941 - val_loss: 0.0937
# Epoch 50/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0940 - val_loss: 0.0939
# Epoch 51/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0940 - val_loss: 0.0938
# Epoch 52/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - val_loss: 0.0940
# Epoch 53/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 54/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0938
# Epoch 55/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0938
# Epoch 56/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 57/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0939 - val_loss: 0.0936
# Epoch 58/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0937
# Epoch 59/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 60/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 61/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0938
# Epoch 62/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0938
# Epoch 63/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0938 - val_loss: 0.0936
# Epoch 64/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0935
# Epoch 65/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0936
# Epoch 66/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0934
# Epoch 67/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0937 - val_loss: 0.0933
# Epoch 68/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - val_loss: 0.0938
# Epoch 69/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 70/80
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 71/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 72/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0935
# Epoch 73/80
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0936 - val_loss: 0.0933
# Epoch 74/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0935
# Epoch 75/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0934
# Epoch 76/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0936
# Epoch 77/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0933
# Epoch 78/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0937
# Epoch 79/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0935 - val_loss: 0.0932
# Epoch 80/80
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0934 - val_loss: 0.0934

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(autoencoder.predict(x_test_noisy[i].reshape(1, 28, 28, 1)).reshape(28,28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
